# %% [markdown]
# <a href="https://colab.research.google.com/github/Tony14100/portfolio/blob/main/%D0%A0%D0%B0%D1%81%D0%BF%D0%BE%D0%B7%D0%BD%D0%B0%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D1%81%D0%BF%D1%83%D1%82%D0%BD%D0%B8%D0%BA%D0%BE%D0%B2%D1%8B%D1%85_%D1%81%D0%BD%D0%B8%D0%BC%D0%BA%D0%BE%D0%B2_%D0%BB%D0%B5%D1%81%D0%BE%D0%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
mkdir ~/.Kaggle

# %%
cp kaggle.json ~/.kaggle/
# Out:
# cp: cannot create regular file '/root/.kaggle/': Not a directory

# %%
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !kaggle datasets download -d quadeer15sh/augmented-forest-segmentation --unzip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/quadeer15sh/augmented-forest-segmentation
# License(s): other
# ...
#  92% 159M/172M [00:01<00:00, 96.9MB/s]
# 100% 172M/172M [00:01<00:00, 103MB/s]

# %%
import matplotlib.pyplot as plt
import random
import os

# Path to the image directory
image_dir = "/content/Forest Segmented/Forest Segmented/images"

# Get a list of all image files in the directory
image_files = [f for f in os.listdir(image_dir) if os.path.isfile(os.path.join(image_dir, f))]

# Randomly select 3 images
selected_images = random.sample(image_files, 3)

# Display the selected images
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
for i, image_file in enumerate(selected_images):
    image_path = os.path.join(image_dir, image_file)
    try:
        img = plt.imread(image_path)
        axes[i].imshow(img)
        axes[i].set_title(image_file)
        axes[i].axis('off')
    except Exception as e:
        print(f"Error loading image {image_file}: {e}")
plt.show()

# %%
# !pip install ultralytics

import matplotlib.pyplot as plt
from ultralytics import FastSAM

# Define an inference source
source = "/content/Forest Segmented/Forest Segmented/images/10452_sat_08.jpg"

# Create a FastSAM model
model = FastSAM("FastSAM-s.pt") # or FastSAM-x.pt

# Assuming 'results' from the previous code is still available
# If not, rerun the inference part with the desired image and prompts

# Assuming you want to identify only the forest in the image
#  Modify the text prompt to be more specific if needed
results = model(source, texts="forest")


plt.figure(figsize=(10, 10))
plt.imshow(results[0].plot())
plt.axis('off')
plt.show()
# Out:
# ...
#
# image 1/1 /content/Forest Segmented/Forest Segmented/images/10452_sat_08.jpg: 640x640 1 object, 1417.9ms
# Speed: 7.0ms preprocess, 1417.9ms inference, 5500.8ms postprocess per image at shape (1, 3, 640, 640)
